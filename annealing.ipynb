# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, BatchNormalization, ReLU, Dropout
from tensorflow.keras.models import Model, clone_model
from itertools import product

import functions as fs
from functions import make_state, run, get_optimal_value, get_optimal_action, get_optimal_actions, get_model_actions, test_model, test_model_accuracy, one_batch_supervised, train_supervised, create_model

# %% [markdown]
# 从原理上讲，退火是错误做法。

# %%
def one_batch(model, batch_size, temperature=1, n_test_rounds=0):
    y_target_list = []
    state_list = np.array([make_state() for i in np.arange(batch_size)])
    prob_list = model(np.array(state_list)).numpy()
    actions = get_model_actions(model, state_list)
    for i, prob in enumerate(prob_list):
        y_target = np.zeros(8)
        state = state_list[i]
        prob_w = prob ** (1/temperature)
        action = np.random.choice(8, p=prob_w/sum(prob_w))
        y_target[action] = run(state, action)
        y_target_list.append(y_target)
    model.fit(state_list, np.array(y_target_list), verbose = 0)
    if n_test_rounds > 0:
        return (test_model(model, n_test_rounds))

def train(model, max_batch=200, batch_size=128, temperature = 1, temperature_decay=1, n_test_rounds=10000, verbose = 0):
    best_weights = []
    best_idx = 0
    best_score = 0
    for i in np.arange(max_batch):
        score = one_batch(model, batch_size, temperature * temperature_decay ** i, n_test_rounds)
        if best_score < score:
            best_score = score
            best_idx = i
            best_weights = model.get_weights()
        if verbose == 1:
            print(i, score)
    return best_idx, best_score, best_weights

# %% [markdown]
# ## 试验场

# %%
model = create_model(n_hidden_layers=1, n_dense_units=512, ratio_dropout=0.5, optimizer='adam')

# %%
best_idx, best_score, best_weights = train(model, 200, temperature = 1, temperature_decay=0.99, verbose = 1)
# Out:
# 0 0.3284540059023309
# 1 0.4022597860125601
# 2 0.45626623391189625
# 3 0.5206979608814543
# 4 0.5884860416710926
# 5 0.6468177393013881
# 6 0.682235846508349
# 7 0.686716036526123
# 8 0.7173011441218551
# 9 0.7427781225648772
# 10 0.7338219146320922
# 11 0.720679048890288
# 12 0.743526187754808
# 13 0.7480147719199366
# 14 0.7305075220655389
# 15 0.7193883371208767
# 16 0.7526526513997959
# 17 0.7577204666473379
# 18 0.7789776038705098
# 19 0.8000758831170246
# 20 0.7898571265549253
# 21 0.7894862465403368
# 22 0.8029533611084658
# 23 0.8224547572691916
# 24 0.8262668243773243
# 25 0.8196763331798106
# 26 0.832445669073789
# 27 0.8228846959715383
# 28 0.8152031095123063
# 29 0.7989919900971613
# 30 0.7811476671064066
# 31 0.7674382677789535
# 32 0.7571176007343585
# 33 0.7672342627939801
# 34 0.8099320579563648
# 35 0.8156895591087203
# 36 0.8195363252437792
# 37 0.8159636668697668
# 38 0.801079007467903
# 39 0.8185260018499843
# 40 0.7886941568321932
# 41 0.7639692807137606
# 42 0.7934787314282901
# 43 0.8211074455247174
# 44 0.810289280049785
# 45 0.823784638632082
# 46 0.8175105362065146
# 47 0.8029677287359049
# 48 0.8175980812011435
# 49 0.8413085879685528
# 50 0.839890302698539
# 51 0.8474595963294309
# 52 0.8520363302430949
# 53 0.8536476660675598
# 54 0.8457174736249519
# 55 0.8457487104533753
# 56 0.8453957769029483
# 57 0.8333579245643629
# 58 0.8291818263663605
# 59 0.830918786893113
# 60 0.8377930250277311
# 61 0.8460634240824653
# 62 0.8499122052234755
# 63 0.8408010801641577
# 64 0.8472174575686607
# 65 0.857200270357817
# 66 0.8552757818625257
# 67 0.8697402789520584
# 68 0.8569727675554776
# 69 0.858097758532536
# 70 0.8471711915653816
# 71 0.8463085305063838
# 72 0.8370830494722964
# 73 0.8412240158186882
# 74 0.8501699918014701
# 75 0.8491827149230752
# 76 0.846668294692294
# 77 0.8577334206243562
# 78 0.8458338246287745
# 79 0.847710391248556
# 80 0.8483117776308956
# 81 0.8479675764629372
# 82 0.829817525160012
# 83 0.8105396286405602
# 84 0.8116604402231493
# 85 0.8210200363681417
# 86 0.8308220032349516
# 87 0.83145545147283
# 88 0.8273941855929672
# 89 0.8166063114983896
# 90 0.8191466753623321
# 91 0.8136102224455414
# 92 0.824507341143154
# 93 0.832188982113498
# 94 0.835771767775518
# 95 0.8377452682468516
# 96 0.8266152905407024
# 97 0.8300072429832173
# 98 0.8269994936496438
# 99 0.8349709166141963
# 100 0.8431046466526816
# 101 0.8445753039248557
# 102 0.8574593690085399
# 103 0.8409564003119314
# 104 0.8379966543099187
# 105 0.8376576023324301
# 106 0.8421696462447424
# 107 0.8444282093999762
# 108 0.8368711550394633
# 109 0.8325124096770613
# 110 0.8285066089075724
# 111 0.8304106245464605
# 112 0.8331136759661391
# 113 0.8336167189531981
# 114 0.8372718437990894
# 115 0.8415247541084132
# 116 0.8344489463409333
# 117 0.8333019707329047
# 118 0.8125360609974311
# 119 0.8053707089951198
# 120 0.8139011052005353
# 121 0.8275425150802572
# 122 0.8362084283866384
# 123 0.8127797900991518
# 124 0.8142108880617408
# 125 0.8011557420587972
# 126 0.8095222192518186
# 127 0.8114706504163767
# 128 0.8170793952317712
# 129 0.8101477718800102
# 130 0.8231747454896878
# 131 0.8191037833014667
# 132 0.8140915953754876
# 133 0.8042146478414441
# 134 0.8016539461512268
# 135 0.802935772405219
# 136 0.8079676599891189
# 137 0.7916058548966631
# 138 0.7752619933319674
# 139 0.7900877267231712
# 140 0.7837392684171441
# 141 0.7853010371073789
# 142 0.801731419137036
# 143 0.8077618077894118
# 144 0.7915490326882572
# 145 0.786760115909959
# 146 0.789532256106423
# 147 0.804033129885484
# 148 0.7935138587083518
# 149 0.7998513880292785
# 150 0.800724096089065
# 151 0.800644682127061
# 152 0.8011514198479863
# 153 0.7947939472165186
# 154 0.8002540978879892
# 155 0.8033439085956455
# 156 0.7913389490547559
# 157 0.7661564780231593
# 158 0.7570389798524186
# 159 0.7690357100284224
# 160 0.8041186627512572
# 161 0.7967875119717931
# 162 0.7812844310381409
# 163 0.7723539555534912
# 164 0.7613465689754007
# 165 0.7652777967845137
# 166 0.7517821691458731
# 167 0.7498779201042141
# 168 0.7498490471535338
# 169 0.7313068491190857
# 170 0.7610925844227404
# 171 0.7534846062040379
# 172 0.7626221438137796
# 173 0.734955891856454
# 174 0.7131935132591493
# 175 0.714165406129149
# 176 0.7424776308608345
# 177 0.7525420689650612
# 178 0.7481670679162027
# 179 0.7469849868100575
# 180 0.7055431049776978
# 181 0.7029344231096578
# 182 0.6942687147898532
# 183 0.7049316333279908
# 184 0.7282999167862436
# 185 0.7107128550536589
# 186 0.6853418341072098
# 187 0.7053662726481529
# 188 0.728733833611617
# 189 0.708865525577257
# 190 0.6887556026101496
# 191 0.6779171154796543
# 192 0.6660686809193352
# 193 0.6709918643785661
# 194 0.6966032485864938
# 195 0.6754750431773519
# 196 0.679024423233917
# 197 0.713390468804659
# 198 0.7011221954804707
# 199 0.6822962889168691

# %%
best_model = clone_model(model)
best_model.set_weights(best_weights)

# %%
test_model(best_model, 10000)
# Out:
# np.float64(0.8623330038084214)

# %%
test_model(model, 10000)
# Out:
# np.float64(0.6843864446513317)

# %%
model.weights[0][0][0:50]
# Out:
# <tf.Tensor: shape=(50,), dtype=float32, numpy=
# array([-0.10846302, -0.09363967, -0.10256259, -0.12220611, -0.10043977,
#        -0.12048358, -0.1143779 , -0.11061859, -0.0819042 , -0.07944234,
#        -0.08579838, -0.11133981, -0.110672  , -0.09598734, -0.11081921,
#        -0.11012349, -0.08634783, -0.10418039, -0.08456437, -0.09229805,
#        -0.10732491, -0.11185248, -0.11535256, -0.10148907, -0.09869622,
#        -0.11056221, -0.09000882, -0.09208713, -0.0598283 , -0.08720026,
#        -0.12041785, -0.08431211, -0.09904582, -0.11579016, -0.0793704 ,
#        -0.14844064, -0.08551419, -0.09759018, -0.068274  , -0.04889043,
#        -0.08643989, -0.11690804, -0.11649935, -0.09219953, -0.09040482,
#        -0.10047588, -0.06579048, -0.07924906, -0.0832098 , -0.11246671],
#       dtype=float32)>

# %%
model = create_model(n_hidden_layers=1, n_dense_units=512, ratio_dropout=0.5, optimizer='adam')

# %%
best_idx, best_score, best_weights = train(model, 200, verbose = 1)
# Out:
# 0 0.5384590436273902
# 1 0.5802635910321251
# 2 0.621978251992235
# 3 0.6276948273397991
# 4 0.6201411553365314
# 5 0.609711337373402
# 6 0.6275114149421601
# 7 0.6567337131945155
# 8 0.6817516983119097
# 9 0.6652173237828999
# 10 0.6713429487339408
# 11 0.6725951244218431
# 12 0.6771233117106743
# 13 0.7039295493171229
# 14 0.7086510551725765
# 15 0.722676334719705
# 16 0.7223673563920436
# 17 0.7266063197369507
# 18 0.7427527924488475
# 19 0.7466812674037772
# 20 0.7524916429584869
# 21 0.7619961980648793
# 22 0.7670574198074354
# 23 0.7705762953094916
# 24 0.7654734384561419
# 25 0.7465809346063639
# 26 0.7357507957453797
# 27 0.7079083583262262
# 28 0.7293564258579629
# 29 0.7385657239832059
# 30 0.7587864404239651
# 31 0.7725162060605284
# 32 0.7808285903241933
# 33 0.78389041610854
# 34 0.769716099446532
# 35 0.7588301475199908
# 36 0.753411480510833
# 37 0.7912128948844114
# 38 0.7812121012974997
# 39 0.7834453888504027
# 40 0.7918727382270087
# 41 0.7942026738951611
# 42 0.8090397979623203
# 43 0.8228972351756485
# 44 0.8371817517215754
# 45 0.8079173262752348
# 46 0.7688272152653324
# 47 0.7841799029237713
# 48 0.8326710635201092
# 49 0.8612280057878701
# 50 0.865720478934714
# 51 0.8443932295681956
# 52 0.831703980020149
# 53 0.827411028070258
# 54 0.8213304144041583
# 55 0.8209086039835273
# 56 0.8099043489375272
# 57 0.8185104820913776
# 58 0.8292497404963151
# 59 0.8685895617654984
# 60 0.8692727927094817
# 61 0.8511712080674919
# 62 0.8561493866922106
# 63 0.8550197315638663
# 64 0.8728731785023285
# 65 0.8756384315527839
# 66 0.8699620788476438
# 67 0.874760733210242
# 68 0.8790488632905256
# 69 0.888276853126741
# 70 0.8936945412888712
# 71 0.8921441987135462
# 72 0.89306923768387
# 73 0.8684010538566781
# 74 0.8606100918165716
# 75 0.8769581639644212
# 76 0.8788576380996314
# 77 0.8753524668258973
# 78 0.8565110412798269
# 79 0.8689956836153757
# 80 0.8664524367827897
# 81 0.8781487295084985
# 82 0.890687221590892
# 83 0.8855697633585314
# 84 0.8829115416086535
# 85 0.8804055700444436
# 86 0.8896506268157156
# 87 0.8887735447066534
# 88 0.8875216594640728
# 89 0.8677809971254122
# 90 0.8775894209666533
# 91 0.8852433656655918
# 92 0.8789399400376011
# 93 0.8796539471814436
# 94 0.8911027389085111
# 95 0.8861314711336404
# 96 0.8894012150049116
# 97 0.8961441803186495
# 98 0.883933567297136
# 99 0.8755040539588208
# 100 0.8639404707515475
# 101 0.8644085861850072
# 102 0.8747766579641201
# 103 0.8679002890594524
# 104 0.8802998839619968
# 105 0.870266972647588
# 106 0.8804841083998232
# 107 0.8735664531585561
# 108 0.866194266253123
# 109 0.8730334276547972
# 110 0.8748546337157226
# 111 0.8765271648743488
# 112 0.8706490458352264
# 113 0.868386628109577
# 114 0.8725028324310308
# 115 0.8720436067411989
# 116 0.8749559889504342
# 117 0.8726303630493201
# 118 0.852409498327487
# 119 0.8544069763397185
# 120 0.8607719623754668
# 121 0.8713134605606536
# 122 0.8727108723817298
# 123 0.8747837746723249
# 124 0.8744091772671855
# 125 0.8762869421279462
# 126 0.8618900536036969
# 127 0.8572777537472445
# 128 0.8528192160928105
# 129 0.846875999325229
# 130 0.848688287609025
# 131 0.8530935041561708
# 132 0.8622897851260601
# 133 0.8461502984177259
# 134 0.8381942001527927
# 135 0.8592445364986651
# 136 0.8641032850496129
# 137 0.8588576200693231
# 138 0.8552605982940473
# 139 0.8573719549703989
# 140 0.8661441234639172
# 141 0.8726938479055152
# 142 0.8692401324570234
# 143 0.8557130107814499
# 144 0.8499392310593448
# 145 0.8461070909107302
# 146 0.8458247233454095
# 147 0.8502101825448001
# 148 0.8534298285914823
# 149 0.8560931295897323
# 150 0.8613053287153256
# 151 0.8597221815105529
# 152 0.8467126890548405
# 153 0.849124281146988
# 154 0.8553370714664835
# 155 0.8519057095573976
# 156 0.8533498262943547
# 157 0.8425205556000399
# 158 0.8350641543399492
# 159 0.8366687014515907
# 160 0.8387432530302007
# 161 0.8293585531477069
# 162 0.8298221240495357
# 163 0.8072691639532141
# 164 0.8154902939110841
# 165 0.8282197562860923
# 166 0.8201328047848522
# 167 0.8133960963179407
# 168 0.8086352083185093
# 169 0.8102543731942378
# 170 0.8097104245741706
# 171 0.8224461637041952
# 172 0.8304262542478204
# 173 0.821747003434689
# 174 0.802315019757298
# 175 0.8087938077544207
# 176 0.8331852288631271
# 177 0.8262588028107289
# 178 0.8139200437147555
# 179 0.7916874351955648
# 180 0.7916294714651009
# 181 0.7978761117239985
# 182 0.8169767284767285
# 183 0.8129808899834268
# 184 0.7967004720414308
# 185 0.8065566875618828
# 186 0.8185836479829696
# 187 0.8037080474738718
# 188 0.7927019081917903
# 189 0.7886028180463318
# 190 0.8003490968990783
# 191 0.8092601084974634
# 192 0.8023433797797198
# 193 0.8086305748266807
# 194 0.7712609923624457
# 195 0.7705072081044535
# 196 0.7930087007258472
# 197 0.8079275635133725
# 198 0.7928287011122944
# 199 0.7707682611624812

# %%
best_model = clone_model(model)
best_model.set_weights(best_weights)

# %%
test_model(best_model, 10000)
# Out:
# np.float64(0.8896954295441154)

# %%
test_model(model, 10000)
# Out:
# np.float64(0.7700434048465293)

# %%
model.weights[0][0][0:50]
# Out:
# <tf.Tensor: shape=(50,), dtype=float32, numpy=
# array([-0.13171698, -0.07805236, -0.19163772, -0.16469546, -0.13337971,
#        -0.15413234, -0.18378848, -0.13037446, -0.20202072, -0.10383993,
#        -0.11229815, -0.14827262, -0.12645932, -0.12167479, -0.06546519,
#        -0.03052763, -0.16950527, -0.14042017, -0.03947781, -0.03243637,
#        -0.14985435, -0.07508776, -0.20118535, -0.15045352, -0.1472116 ,
#        -0.06761225, -0.13061437, -0.20624864, -0.0611332 , -0.09138539,
#        -0.109717  , -0.1518251 , -0.13589486, -0.08704136, -0.12082373,
#        -0.14995103, -0.14566788, -0.22887288, -0.01483672, -0.16935329,
#        -0.05852098, -0.15049323, -0.1335745 , -0.10824125, -0.10736649,
#        -0.16560148, -0.1655342 , -0.14645581, -0.15772112, -0.08011957],
#       dtype=float32)>

# %% [markdown]
# 看上去退火确实使模型表现变差了

# %%
np.sum(model.weights[1].numpy()>0)
# Out:
# np.int64(246)

# %%
np.sum(np.abs(model.weights[1].numpy()) > 0.05)
# Out:
# np.int64(1)
